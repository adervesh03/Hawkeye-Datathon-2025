# %% [markdown]
# # Model Implementation

# %% [markdown]
# ## Initialize Packages

# %%
import xgboost as xgb
import sys
import pandas as pd
import numpy as np
import os
import rich

# %% [markdown]
# # XGBoost

# %% [markdown]
# # Variable Reduction
