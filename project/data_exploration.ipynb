# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Initialize Packages

# %%
import pandas as pd
import numpy as np
import os
import rich

# %% [markdown]
# ## Target Variable Analysis
#
# Our target variable is the expected loss per policy: Expected Loss = Claim Cost (claimcst0) / Exposure

# %%
model_data = pd.read_csv('synthetic_auto_policies_model_data_10042025.csv')

# %%
model_data['expected_loss'] = model_data['claimcst0'] / model_data['exposure']
